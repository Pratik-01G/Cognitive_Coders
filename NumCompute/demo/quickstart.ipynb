# %%
import sys
sys.path.append("/Users/vivek/Desktop/AI/Cognitive_Coders/NumCompute")

# %%
from numcompute.io import CSVReader
from numcompute.preprocessing import StandardScaler
from numcompute.sort_search import topk

# %% [markdown]
# read csv

# %%
reader = CSVReader(
    filepath="titanic_dataset.csv",   # path to CSV file
    delimiter=",",
    has_header=True,
    dtype=None              # auto-infer dtype
)

# Read full CSV
data = reader.read()

print("Dataset Shape:")
print(data.shape)

print("\nFirst 5 Rows:")
print(data[:5])

print("\nHeader:")
print(reader.header)
# Out:
# Dataset Shape:
# (418, 13)
#
# First 5 Rows:
# [['892' '0' '3' '"Kelly' 'Mr. James"' 'male' '34.5' '0' '0' '330911'
#   '7.8292' nan 'Q']
#  ['893' '1' '3' '"Wilkes' 'Mrs. James (Ellen Needs)"' 'female' '47' '1'
#   '0' '363272' '7' nan 'S']
#  ['894' '0' '2' '"Myles' 'Mr. Thomas Francis"' 'male' '62' '0' '0'
#   '240276' '9.6875' nan 'Q']
#  ['895' '0' '3' '"Wirz' 'Mr. Albert"' 'male' '27' '0' '0' '315154'
#   '8.6625' nan 'S']
#  ['896' '1' '3' '"Hirvonen' 'Mrs. Alexander (Helga E Lindqvist)"'
#   'female' '22' '1' '1' '3101298' '12.2875' nan 'S']]
#
# Header:
# ['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked']

# %% [markdown]
# preprocess

# %%
X_numeric = data[:, [5, 6 9]].astype(float)

print("\nOriginal Numerical Features:")
print(X_numeric[:5])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 X_numeric = data[:, [7, 9]].astype(float)
#       3 print("\nOriginal Numerical Features:")
#       4 print(X_numeric[:5])
#
# ValueError: could not convert string to float: 'A/4 48871'

# %% [markdown]
# sort_search

# %% [markdown]
# stats

# %% [markdown]
# estimating gradients

# %% [markdown]
# benchmark
