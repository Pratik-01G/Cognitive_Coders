# %%
import sys
sys.path.append("/Users/vivek/Desktop/AI/Cognitive_Coders/NumCompute")

# %%
from numcompute.io import CSVReader
from numcompute.preprocessing import StandardScaler
from numcompute.sort_search import topk

# %%
# !ls
# Out:
# Final Excel - Sheet1.csv quickstart.ipynb

# %%
reader = CSVReader("50L.csv")

data = reader.read()
print(data)
# Out:
# [['0' 'new' '1814']
#  ['1' 'ilo' '1229']
#  ['2' 'want' '785']
#  ['3' 'your' '2432']
#  ['4' 'ita' '1082']
#  ['5' 'thaklo' '114']
#  ['6' 'shesh' '40']
#  ['7' 'fill' '313']
#  ['8' 'theke' '15946']
#  ['9' 'dixit' '10']
#  ['10' 'together' '78']
#  ['11' 'would' '162']
#  ['12' 'didi' '3307']
#  ['13' 'send' '2542']
#  ['14' 'sound' '256']
#  ['15' 'bes' '918']
#  ['16' 'klk' '725']
#  ['17' 'sasur' '55']
#  ['18' 'hour' '96']
#  ['19' 'off' '4077']
#  ['20' 'jegulo' '215']
#  ['21' 'sesh' '1323']
#  ['22' 'ota' '6498']
#  ['23' 'install' '152']
#  ['24' 'thekei' '863']
#  ['25' 'diner' '431']
#  ['26' 'there' '334']
#  ['27' 'have' '1450']
#  ['28' 'side' '706']
#  ['29' 'shoes' '162']
#  ['30' 'solution' '105']
#  ['31' 'hee' '251']
#  ['32' 'chill' '158']
#  ['33' 'wants' '39']
#  ['34' 'hoye' '19055']
#  ['35' 'kta' '962']
#  ['36' 'thankyou' '46']
#  ['37' 'dito' '398']
#  ['38' 'cheye' '445']
#  ['39' 'admit' '152']
#  ['40' 'chhere' '50']
#  ['41' 'souvik' '82']
# ...
